# %%
#import the various different libraries
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
#load the data sets, make sure they read correctly
species=pd.read_csv("species_info.csv")
print(species.head())
observations=pd.read_csv("observations.csv")
print(observations.head())
# Out:
#   category                scientific_name  \
# 0   Mammal  Clethrionomys gapperi gapperi
# 1   Mammal                      Bos bison
# 2   Mammal                     Bos taurus
# 3   Mammal                     Ovis aries
# 4   Mammal                 Cervus elaphus
#
#                                         common_names conservation_status
# 0                           Gapper's Red-Backed Vole                 NaN
# 1                              American Bison, Bison                 NaN
# 2  Aurochs, Aurochs, Domestic Cattle (Feral), Dom...                 NaN
# 3  Domestic Sheep, Mouflon, Red Sheep, Sheep (Feral)                 NaN
# 4                                      Wapiti Or Elk                 NaN
#             scientific_name                            park_name  observations
# 0        Vicia benghalensis  Great Smoky Mountains National Park            68
# 1            Neovison vison  Great Smoky Mountains National Park            77
# 2         Prunus subcordata               Yosemite National Park           138
# 3      Abutilon theophrasti                  Bryce National Park            84
# 4  Githopsis specularioides  Great Smoky Mountains National Park            85

# %%
#Question 1: How many species are endangered?
endangered_species=len(species[species["conservation_status"] == "Endangered"])
print("The number of endangered species is",endangered_species)
# Out:
# The number of endangered species is 16

# %%
#Question 2: How many species are species of concern
species_of_concern=len(species[species["conservation_status"] == "Species of Concern"])
print("The number of species of concern is", species_of_concern)
# Out:
# The number of species of concern is 161

# %%
#Question 3: How many species are threatened?
threatened_species=len(species[species["conservation_status"] == "Threatened"])
print("The number of threatened species is", threatened_species)
# Out:
# The number of threatened species is 10

# %%
#Question 4: How many species are in recovery? 
recovery_species=len(species[species["conservation_status"] == "In Recovery"])
print("The number of recovery species is", recovery_species)
# Out:
# The number of recovery species is 4

# %%
#Question 5 Visualise the number of species of each Conservation status
data=[endangered_species,species_of_concern,threatened_species,recovery_species]
labels=["Endangered Species","Species of Concern","Threatened Species"," In Recovery Species"]
plt.figure(figsize=(8,10))
plt.pie(data,labels=labels, autopct='%.0f%%')
plt.title("Proportion of Species by Conservation Status")
plt.show()
print("Looking at the graph the majority of species in this dataset sit in the species of concern (84%). Very few species are engangered and even fewer species are in recovery.")
# Out:
# Looking at the graph the majority of species in this dataset sit in the species of concern (84%). Very few species are engangered and even fewer species are in recovery.

# %%
#Question 6: Which category has the most endangered, species of concern, threatened and In Recovery
plt.figure(figsize=(8,10))
sns.countplot(data=species,x="conservation_status",hue="category")
plt.title("Count of category of species by conservation status")
plt.xlabel("Conservation Status")
plt.ylabel("Count")
plt.legend(loc=1)
plt.show()
print("Within the conservation status of the species it has been broken down into their respective categories. Within species of concern the category of animal mostly effected is Bird, for endangered it is Mammal, for threatened it is Fish and in recovery it is Bird.")
# Out:
# Within the conservation status of the species it has been broken down into their respective categories. Within species of concern the category of animal mostly effected is Bird, for endangered it is Mammal, for threatened it is Fish and in recovery it is Bird.

# %%
#Question 7: How many parks are there? Names of the parks?
num_of_parks=len(observations.park_name.unique())
park_names=observations.park_name.unique()
print(num_of_parks)
print(park_names)
# Out:
# 4
# ['Great Smoky Mountains National Park' 'Yosemite National Park'
#  'Bryce National Park' 'Yellowstone National Park']

# %%
#Question 8: Which park has the most animals
plt.figure(figsize=(8,10))
ax=sns.countplot(data=observations,x="park_name")
plt.title("Nmber of Species in each Park")
plt.axis([-0.5,4,5000,6000])
plt.xlabel("Park Name")
plt.ylabel("Count")
ax.set_xticklabels(ax.get_xticklabels(),rotation=35)
plt.show()
print("Each park has the same number of species. No park has more species than the other.")
# Out:
# Each park has the same number of species. No park has more species than the other.

# %%
#Question 9: Which park has the most animals broken out by category?
merged_df=pd.merge(species,observations, on="scientific_name")
plt.figure(figsize=(12,10))
ax=sns.countplot(data=merged_df,x="park_name",hue="category")
plt.title("Number of Species in each Park by Category")
plt.axis([-0.5,4,0,5000])
plt.xlabel("Park Name")
plt.ylabel("Count")
ax.set_xticklabels(ax.get_xticklabels(),rotation=35)
plt.legend(loc=9)
plt.show()
print("The breakdown of species category is the same in each park.")
# Out:
# The breakdown of species category is the same in each park.

# %%
#Question 10 Which Park has the most observations? Which park has the most observations by category?
plt.figure(figsize=(8,12))
plt.subplot(2,1,1)
plt.subplots_adjust(hspace=0.8)
ax=sns.barplot(data=merged_df,x="park_name",y="observations",estimator=sum)
ax.set_xticklabels(ax.get_xticklabels(),rotation=35)
plt.title("Number of Total Observations by Park")
plt.xlabel("Park Name")
plt.subplot(2,1,2)
ax=sns.barplot(data=merged_df,x="park_name",y="observations",estimator=sum,hue="category")
ax.set_xticklabels(ax.get_xticklabels(),rotation=35)
plt.title("Number of Observation by Category by Park")
plt.xlabel("Park Name")
       
plt.show()
print("The total number of observation by park varies, the park with the most observation is Yellowstone National Park. The park with the least observations is Great Smoky Mountains National Park. Looking at the observations broken down by category in each park the most observations were Vascular Plants followed by Birds.")
# Out:
# The total number of observation by park varies, the park with the most observation is Yellowstone National Park. The park with the least observations is Great Smoky Mountains National Park. Looking at the observations broken down by category in each park the most observations were Vascular Plants followed by Birds.
